# %% [markdown]
# <a href="https://colab.research.google.com/github/mritogether/ESMRMB2024_Hardware_to_Map/blob/main/02_sequence_design_for_mapping/notebooks/s00_fid_sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # s00_fid (solution)
# FID is the simpliest sequence but this does not mean it is not important:) Now, let's build FID together and kick off the Pulseq game in Colab!
#
# **Exercise**
# If you have no clue, search "hint" for hints.
# 1. Go through the whole sequence source code and then run it to get familiar with Pulseq programming in Google CoLab.
# **Answer:** Click "Runtime" -> "Run all" to execute the script.
# 2. Observe the simulated signal and the reconstructed spectrum. Why do we see only a decay and not a damped oscillation in the simulated signal? Increase the number of ADC samples (nRD) and ADC duration (sampling_time), and see the prolonged signal decay.
# **Answer:**: In principle, the simulated signal is proportional to the transversal magnetization: S(t)~Mxy(t)=Mxy(t=0)exp(-i*gamma(B0+dB0)t) (ignore relaxation). There is a phase evolution over time. In the pixel phantom, B0=0, i.e. the Larmor frequency is 0, which means the simulated signal is demodulated. Since dB0 = 0, there is no phase evolution and thus the simulated signal is only a decay and not a damped oscillation. Change nRD from 40 to 400 and sampling_time from 4.2e-3 to 42e-3, and then the delay is prolonged.
# 3. Is the decay of the FID given by T1, T2, or T2*? Estimate the numerical value of the decay rate R (or relaxation time T=1/R) of the FID signal.
# **Answer:** The decay is given by T2star. The simulated FID singal is propotional to the transversal magnetization, Mxy(t)=Mxy(t=0)exp(-i*gamma(B0+dB0)t)exp(-t/T2star), at the time T2star, S(T2star)=1/e S(t=0) = 0.368 S(t=0), so the relaxation time, T2star is about 30 ms.
# 4. Change the echo time (TE) to 15 ms and repetition time (TR) to 300 ms.
# **Answer:** One way to change TE is to change the delay of ADC. The TR = 300 ms can be achieved by adding a calculated fill time at the end of ADC through the function: mr.makeDelay().
# 5. (Optional) Search for the B0 inhomogeneity of the object (dB0). In the on-resonant case this is 0. By changing the value (e.g. dB0 = 500), you can mimic the laboratory frame dynamic and observe a frequency shift in the reconstructed 1D spectrum.
# **Answer:** make dB0 = 500, then we can see the oscillation and frequency shift in the reconstructed 1D spectrum.
# 6. (Optional) Set dB0=0 and alter the RF phase offset and ADC phase offset. What do you observe? What is the most general condition to get a real positive signal?
# **Answer:** The real and imaginary components change but the absolute value remains the same. This is because the phase offset difference between RF and ADC will produce a phase offset in the simulated signal. When RF and ADC are in phase (i.e. their phase offsets are the same), we can get a real positive signal.

# %%
#@title FID - environment setup (just need to run it once)
# !pip show pypulseq || pip install pypulseq &> /dev/null
import math
import warnings
import numpy as np
from matplotlib import pyplot as plt
import pypulseq as pp
# for simulation
# !pip show MRzeroCore || pip install MRzeroCore
import MRzeroCore as mr0
import torch
# Out:
# WARNING: Package(s) not found: pypulseq
# /usr/local/lib/python3.10/dist-packages/sigpy/config.py:15: UserWarning: Importing cupy failed. For more details, see the error stack below:
#
# ================================================================
# Failed to import CuPy.
#
# If you installed CuPy via wheels (cupy-cudaXXX or cupy-rocm-X-X), make sure that the package matches with the version of CUDA or ROCm installed.
#
# On Linux, you may need to set LD_LIBRARY_PATH environment variable depending on how you installed CUDA/ROCm.
# On Windows, try setting CUDA_PATH environment variable.
#
# Check the Installation Guide for details:
#   https://docs.cupy.dev/en/latest/install.html
#
# Original error:
#   ImportError: libcuda.so.1: cannot open shared object file: No such file or directory
# ================================================================
#
#   warnings.warn(
# WARNING: Package(s) not found: MRzeroCore
# Collecting MRzeroCore
#   Downloading MRzeroCore-0.3.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (2.4.1+cu121)
# Requirement already satisfied: pypulseq in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (1.4.2)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (3.7.1)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (1.13.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (2.32.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from MRzeroCore) (0.24.0)
# Collecting torchkbnufft (from MRzeroCore)
#   Downloading torchkbnufft-1.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting pydisseqt>=0.1.4 (from MRzeroCore)
#   Downloading pydisseqt-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (853 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->MRzeroCore) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->MRzeroCore) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->MRzeroCore) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->MRzeroCore) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->MRzeroCore) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->MRzeroCore) (2024.6.1)
# Requirement already satisfied: coverage>=6.2 in /usr/local/lib/python3.10/dist-packages (from pypulseq->MRzeroCore) (7.6.1)
# Requirement already satisfied: sigpy>=0.1.26 in /usr/local/lib/python3.10/dist-packages (from pypulseq->MRzeroCore) (0.1.26)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->MRzeroCore) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->MRzeroCore) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->MRzeroCore) (0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->MRzeroCore) (1.16.0)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.10/dist-packages (from sigpy>=0.1.26->pypulseq->MRzeroCore) (1.7.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from sigpy>=0.1.26->pypulseq->MRzeroCore) (0.60.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sigpy>=0.1.26->pypulseq->MRzeroCore) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->MRzeroCore) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12->MRzeroCore) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->sigpy>=0.1.26->pypulseq->MRzeroCore) (0.43.0)
# Downloading MRzeroCore-0.3.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 24.7 MB/s eta 0:00:00
# Downloading pydisseqt-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.5/454.5 kB 31.9 MB/s eta 0:00:00
# Downloading torchkbnufft-1.4.0-py3-none-any.whl (37 kB)
# Installing collected packages: pydisseqt, torchkbnufft, MRzeroCore
# Successfully installed MRzeroCore-0.3.5 pydisseqt-0.1.5 torchkbnufft-1.4.0

# %%
#@title FID - sequence
experiment_id = 's00_fid'
# %% SETUP system
# choose the scanner limits
system = pp.Opts(
        max_grad=25,       # the portable scanner's limits are 25, 40 and 35 mT/m for X, Y and Z axes
        grad_unit="mT/m",
        max_slew=50,       # the portable scanner's limits are 50, 80 and 70 mT/m/ms for X, Y and Z, respectively
        slew_unit="T/m/s",
        rf_ringdown_time=15e-6,
        rf_dead_time=15e-6,
        adc_dead_time=0e-6 )
# Create a new sequence object
seq = pp.Sequence(system)

# %% DEFINE the sequence and parameters
nRD = 400     # Number of ADC samples
TE = 15e-3 # Echo time
TR = 300e-3  # Repetition time

sampling_time = 42e-3
t_ex  = 60e-6 # [s], duration of the excitation pulse.
rf_ex_phase = np.pi / 2 # phase of the excitation pulse # hint: alter the phase offset of the excitation pulse here

# derived and modifed parameters
TE = round(TE/system.grad_raster_time/2) * system.grad_raster_time * 2 # TE should be divisible to a double gradient raster, which simplifies calcuations
rf_add = math.ceil(max(system.rf_dead_time,system.rf_ringdown_time)/system.grad_raster_time)*system.grad_raster_time # round up dead times to the gradient raster time to enable correct TE calculation

# ======
# CREATE EVENTS
# ======

# excitation pulse
flip_ex = 90 * np.pi / 180
rf_ex = pp.make_block_pulse(
    flip_angle=flip_ex,
    system=system,
    duration=t_ex,
    delay=rf_add,
    phase_offset=rf_ex_phase )

d_ex=pp.make_delay(t_ex+rf_add*2)

adc_delay = system.grad_raster_time * np.round((TE-t_ex/2-rf_add) / system.grad_raster_time)
adc = pp.make_adc(
    num_samples=nRD,
    dwell=sampling_time/nRD,
    delay=adc_delay ) # Hint: change the delay of adc to alter TE

# Fill-times
t_ex = pp.calc_duration(d_ex) # Duration of the excitation pulse object (Deadtime + duration + ringdowntime)
t_adc = pp.calc_duration(adc) # Duration of the ADC event (delay+num_samples*dwell)

TR_fill = TR - t_ex - t_adc
# Round to gradient raster
TR_fill = system.grad_raster_time * np.round(TR_fill / system.grad_raster_time)
if TR_fill < 0:
    TR_fill = 1e-3
    warnings.warn(
        f"TR too short, adapted to: {1000 * (t_ex + t_adc + TR_fill)} ms"
    )
else:
    print(f"TR fill: {1000 * TR_fill} ms")
delay_TR = pp.make_delay(TR_fill)

# ======
# CONSTRUCT SEQUENCE
# ======
seq.add_block(rf_ex, d_ex)
seq.add_block(adc)
seq.add_block(delay_TR)

(ok, error_report) = seq.check_timing()  # Check whether the timing of the sequence is correct
if ok:
    print("Timing check passed successfully")
else:
    print("Timing check failed. Error listing follows:")
    [print(e) for e in error_report]

# ======
# VISUALIZATION
# ======
seq.plot(time_range=(0, TR))

# Plot k-space trajectory
k_traj_adc, k_traj, t_excitation, t_refocusing, t_adc = seq.calculate_kspace()

plt.figure()
plt.plot(k_traj[0],k_traj[1], 'b-')
plt.plot(k_traj_adc[0],k_traj_adc[1],'r.')
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.title('k-space trajectory')
plt.xlabel(r'$k_x \mathregular{\ /m^{-1}}$')
plt.ylabel(r'$k_y \mathregular{\ /m^{-1}}$')
plt.show()

plt.figure()
p1 = plt.plot(k_traj[0], label='k_x')
p2 = plt.plot(k_traj[1], label='k_y')
p3 = plt.plot(k_traj[2], label='k_z')
plt.legend(loc="upper left")
plt.xlabel('#points')
plt.ylabel('$k \mathregular{\ /m^{-1}}$')
ax = plt.gca()
ax.grid();
plt.title('k-space trajectory')
plt.show()

# Prepare the sequence output for the scanner
seq.set_definition('Name', experiment_id)
seq.write(experiment_id+'.seq')
# Out:
# TR fill: 242.95000000000002 ms
# Timing check passed successfully
# 'bc6dcb77f0e8c4c6e53a864b0cc90e86'

# %%
#@title 1D FID in a pixel phantom - simulation
dB0 = 500
obj_p = mr0.CustomVoxelPhantom(
        pos=[[0., 0., 0]],
        PD=[1.0],
        T1=[3.0],
        T2=[0.5],
        T2dash=[30e-3],
        D=[0.0],
        B0=0,
        voxel_size=0.1,
        voxel_shape="box"
    )
# Manipulate loaded data
obj_p.B0+=dB0
obj_p.D*=0
obj_p.plot()
# Convert Phantom into simulation data
obj_p=obj_p.build()

# %% SIMULATE  the external.seq file and add acquired signal to ADC plot
# Read in the sequence
seq0 = mr0.Sequence.import_file(experiment_id + '.seq')
# Simulate the sequence
graph=mr0.compute_graph(seq0, obj_p, 200, 1e-3)
signal=mr0.execute_graph(graph, seq0, obj_p, print_progress=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# CustomVoxelPhantom
# Voxel shape: box
# Voxel size: tensor([0.1000, 0.1000, 0.1000])

# %%
#@title 1D FID in a pixel phantom - reconstruction
# 1D FFT
def fft_1d(x):
    return np.fft.fftshift(np.fft.fftn(np.fft.ifftshift(x)))

# detailed ADC plot for one repetition
plt.figure()
plt.title('ADC signal')
# time axis
time_axis=np.linspace(1, nRD, nRD)*adc.dwell ;
plt.plot(time_axis, np.real(signal), label='real')
plt.plot(time_axis, np.imag(signal), label='imag')
plt.plot(time_axis, np.abs(signal), label='abs')
plt.grid()
plt.legend(loc="upper right")
plt.xlabel('time (ADC)/s')
plt.ylabel('Amplitude')

# FFT reconstruction
spectrum = fft_1d(signal)

# frequency axis
freq_axis = np.linspace(-nRD/2, nRD/2-1, nRD)/(adc.dwell*adc.num_samples) ; # remain to be checked whether -1 should be included or not

plt.figure()
plt.title('spectrum')
plt.plot(freq_axis, np.abs(spectrum))
plt.xlabel('Frequency/Hz')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
